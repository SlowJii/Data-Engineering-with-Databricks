# %%
df1 = spark.read.format("csv").optaion("header", "true").load("dbfs:/FileStore/shared_uploads/hoanglb.b20vt165@stu.ptit.edu.vn/lego_sets.csv")

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql import SparkSession

# %%
df1.show()

# %%
spark_apps = SparkSession.builder \
    .appName("Spark Notebook learning") \
        .master("local[*]") \
            .config("spark.executor.memory", "4g") \
                .config("spark.executor.cores", 4) \
                    .config("spark.executor.instances", 4) \
                        .config("spark.driver.memory", "4g") \
                            .getOrCreate()

spark_read = spark_apps.read.format("csv").option("header","true").load("dbfs:/FileStore/shared_uploads/hoanglb.b20vt165@stu.ptit.edu.vn/lego_sets.csv")
spark_read.show()

# %%
dbutils.help()

# %%
dbutils.fs.help("mount")

# %%
dbutils.fs.ls("/FileStore")

# %%
# %fs dễ sử dụng và cho ra output đẹp hơn là sử dụng dbutils
# %fs
ls /FileStore
