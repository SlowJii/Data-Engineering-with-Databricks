# %%
# %fs
ls 'dbfs:/user/hive/warehouse'

# %%
# %sql
USE CATALOG hive_metastore;
CREATE SCHEMA IF NOT EXISTS querying_file;

CREATE OR REPLACE TEMP VIEW data_source AS
SELECT * FROM read_csv(
  '/Workspace/LEARN/Data-Engineering-with-Databricks/lego_sets.csv',
  map('header', 'true', 'delimiter', ',')
);

CREATE TABLE querying_file.lego AS SELECT * FROM data_source;
