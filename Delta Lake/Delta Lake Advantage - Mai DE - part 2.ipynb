# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *

# %%
# %sql
-- DELTA CACHE
-- SPARK CACHE

# %%
# %sql
/*
Spark cache dữ liệu trên RAM (in-memory)
Delta cache dữ liệu ở trên local machine (local disk của worker node)
Cách sử dụng: Dùng cluster Delta Accelerate - chỉ có ở bản Databricks Pro, cho phép chạy multi node
*/

# %%
# Bật spark.io.cache
spark.conf.set("spark.databricks.io.cache.enabled", "true")

# %%
# %sql
SELECT * FROM taxi_db.trip_delta LIMIT 10;

# %%
# %sql
SELECT vendor_name, sum(Trip_Distance) as Total_Trip_Distance, sum(Total_Amt) as Total_Amount FROM taxi_db.trip_delta GROUP BY vendor_name

# %%
# %sql
/*
Lần đầu truy vấn, cache hit 2% và job chạy mất 5s
Lần thứ hai truy vấn, cache hit 37% và job chạy mất 4s
Lần thứ ba truy vấn, cache hit 52% và job chạy mất 3s
*/

# %%
# %sql
-- Xử lý nhiều file nhỏ với DELTA ENGINE
